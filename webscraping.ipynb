# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import numpy as np

# %%
url = "https://www.carrefoursa.com/pirinc/c/1134?q=%3AbestSeller%3ApackageSize%3A1000G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
products = soup.find_all('div', class_='product_click')
pirinç_names = [product.find('input', {'id': 'productNamePost'}).get('value') for product in products]
pirincfiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

pirincfiyatlarım
# Out:
# [109.94999999999999,
#  69.5,
#  46.5,
#  99.94999999999999,
#  23.9,
#  79.9,
#  49.9,
#  53.9,
#  154.95,
#  64.9,
#  32.9,
#  162.95,
#  169.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=pirin%C3%A7&sayfa=1&sirala=akilli-siralama&kategori=5","https://www.migros.com.tr/arama?q=pirin%C3%A7&sayfa=2&kategori=5&sirala=akilli-siralama"]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')





    prices = []
    product_elements = soup.find_all('fe-product-image')
    for product in product_elements:
        product_name = product.find('img')['alt']  # Extract the 'alt' attribute from the 'img' tag
        pirinç_names.append(product_name)


 
    amount_elements = soup.find_all('div', id='price-new')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)



    # Fiyatları ekrana yazdır
    for price in prices:
        pirincfiyatlarım.append(price)

    driver.quit()

# %%
len(pirincfiyatlarım)
# Out:
# 64

# %%
len(pirinç_names)
# Out:
# 64

# %%
url = "https://www.carrefoursa.com/bulgur/c/1142?q=%3AbestSeller%3ApackageSize%3A1.000G%3ApackageSize%3A1000G%3AinStockFlag%3Atrue&text=#"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
bulgurfiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

bulgurfiyatlarım
# Out:
# [20.0,
#  20.0,
#  39.9,
#  39.9,
#  42.5,
#  39.95,
#  42.5,
#  21.0,
#  39.95,
#  39.9,
#  39.9,
#  42.5,
#  42.5,
#  42.5,
#  39.9,
#  39.9,
#  39.9,
#  174.9,
#  39.9,
#  21.0,
#  42.5,
#  42.5,
#  42.5,
#  39.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/arama?q=bulgur&sayfa=1&kategori=5",
       "https://www.migros.com.tr/arama?q=bulgur&sayfa=2&kategori=5&sirala=akilli-siralama"]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        bulgurfiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/makarna/c/1122?q=%3AbestSeller%3ApackageSize%3A500G&text=#"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
makarnafiyatlarım =2* [float(price_element.get('content')) for price_element in price_elements]

makarnafiyatlarım
# Out:
# [12.899999999999999,
#  20.75,
#  16.9,
#  20.75,
#  20.75,
#  20.75,
#  16.9,
#  20.75,
#  11.0,
#  11.0,
#  16.9,
#  20.75,
#  36.95,
#  11.0,
#  20.75,
#  20.75,
#  20.75,
#  16.9,
#  11.0,
#  20.75,
#  11.0,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  36.95,
#  20.75,
#  20.75,
#  12.899999999999999,
#  20.75,
#  16.9,
#  20.75,
#  20.75,
#  20.75,
#  16.9,
#  20.75,
#  11.0,
#  11.0,
#  16.9,
#  20.75,
#  36.95,
#  11.0,
#  20.75,
#  20.75,
#  20.75,
#  16.9,
#  11.0,
#  20.75,
#  11.0,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  20.75,
#  36.95,
#  20.75,
#  20.75]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/arama?q=makarna&sayfa=1&kategori=10112&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=makarna&sayfa=2&kategori=10112&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=makarna&sayfa=3&kategori=10112&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=makarna&sayfa=4&kategori=10112&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=makarna&sayfa=5&kategori=10112&sirala=akilli-siralama"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        makarnafiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=un%3AbestSeller%3ApackageSize%3A1000G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
unfiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

unfiyatlarım
# Out:
# [27.71,
#  34.9,
#  36.9,
#  43.9,
#  43.9,
#  96.0,
#  46.5,
#  34.9,
#  51.5,
#  73.5,
#  51.5,
#  43.9,
#  31.25,
#  32.5,
#  48.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/arama?q=un&sayfa=1&kategori=5",
       "https://www.migros.com.tr/arama?q=un&sayfa=2&kategori=5&sirala=akilli-siralama"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        unfiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search/?q=bu%C4%9Fday%3AbestSeller%3ApackageSize%3A1000G&text=bu%C4%9Fday#"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
bugdayfiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

bugdayfiyatlarım
# Out:
# [34.9,
#  29.900000000000002,
#  18.9,
#  49.9,
#  60.9,
#  59.9,
#  96.0,
#  87.75,
#  46.5,
#  43.9,
#  48.9,
#  32.5]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/arama?q=bu%C4%9Fday&sayfa=1&kategori=5"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        bugdayfiyatlarım.append(price)

    driver.quit()

# %%
import itertools
import numpy as np
tahıllar=list(itertools.chain(bugdayfiyatlarım,bulgurfiyatlarım))
np.mean(tahıllar)
# Out:
# 53.544512195121946

# %%
url = "https://www.carrefoursa.com/corekler/c/1405?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
fırınfiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

fırınfiyatlarım
# Out:
# [12.5,
#  13.5,
#  63.5,
#  54.9,
#  42.9,
#  36.9,
#  65.9,
#  155.0,
#  13.5,
#  9.9,
#  39.0,
#  42.9,
#  66.5,
#  13.5,
#  135.0,
#  19.9,
#  24.9,
#  42.9,
#  97.9,
#  175.0,
#  91.9,
#  175.0,
#  100.0,
#  140.0,
#  24.9,
#  255.0,
#  40.0,
#  81.5,
#  37.5,
#  69.95,
#  37.9,
#  37.9,
#  37.9,
#  185.0,
#  175.0,
#  16.0,
#  210.0,
#  72.9,
#  79.9,
#  98.9,
#  76.5,
#  109.9,
#  139.9,
#  109.9,
#  119.9,
#  99.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/sabah-sicaklari-c-456?sayfa=1"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                amount_value = float(amount_text.replace(',', '.').replace('TL', ''))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        fırınfiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/kirmizi-etler/c/1045?q=%3AbestSeller%3Acategory%3A1046"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
danafiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

danafiyatlarım
# Out:
# [409.9,
#  435.9,
#  419.9,
#  539.9,
#  539.9,
#  119.9,
#  429.9,
#  577.9,
#  369.9,
#  539.9,
#  684.9,
#  661.9,
#  717.9,
#  895.9,
#  562.9,
#  696.9,
#  696.9,
#  695.9,
#  562.9,
#  696.9,
#  663.9,
#  635.9,
#  696.9,
#  832.9,
#  689.9,
#  684.9,
#  199.9,
#  539.9,
#  279.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/dana-eti-c-3fa",
       "https://www.migros.com.tr/dana-eti-c-3fa?sayfa=2&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        danafiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/kirmizi-etler/c/1045?q=%3AbestSeller%3Acategory%3A1054"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
kuzufiyatlarım = [float(price_element.get('content')) for price_element in price_elements]

kuzufiyatlarım
# Out:
# [495.9,
#  879.9,
#  735.9,
#  540.9,
#  681.9,
#  639.9,
#  794.9,
#  692.9,
#  813.9,
#  695.9,
#  794.9,
#  802.9,
#  813.9,
#  813.9,
#  695.9,
#  989.9,
#  608.9,
#  794.9,
#  664.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/kuzu-eti-c-3fb"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        kuzufiyatlarım.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/pilic/c/1061?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
tavuk = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/hindi/c/1065"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
hindi = [float(price_element.get('content')) for price_element in price_elements]


tavuk=list(itertools.chain(tavuk,hindi))
tavuk
# Out:
# [85.9,
#  179.9,
#  95.4,
#  169.9,
#  86.5,
#  35.9,
#  97.9,
#  91.9,
#  161.3,
#  227.0,
#  300.0,
#  54.9,
#  49.9,
#  179.9,
#  169.9,
#  85.9,
#  97.9,
#  245.9,
#  52.9,
#  179.9,
#  42.9,
#  89.9,
#  182.9,
#  53.9,
#  81.9,
#  245.9,
#  44.9,
#  69.9,
#  28.9,
#  157.9,
#  169.9,
#  246.9,
#  254.9,
#  169.9,
#  47.9,
#  249.75,
#  99.9,
#  159.9,
#  206.0,
#  98.9,
#  179.9,
#  227.9,
#  99.9,
#  106.9,
#  95.9,
#  95.9,
#  106.9,
#  169.9,
#  64.9,
#  59.9,
#  53.9,
#  155.9,
#  256.1,
#  289.9,
#  254.9,
#  115.9,
#  290.9,
#  85.9,
#  99.9,
#  175.0,
#  272.9,
#  85.9,
#  49.9,
#  226.55,
#  100.9,
#  159.9,
#  45.9,
#  200.9,
#  282.9,
#  49.9,
#  39.9,
#  345.9,
#  97.9,
#  649.9,
#  89.9,
#  254.9,
#  108.9,
#  217.9,
#  21.9,
#  8.9,
#  91.9,
#  105.9,
#  95.9,
#  108.9,
#  262.9,
#  181.9,
#  141.9,
#  68.9,
#  91.9,
#  232.9,
#  345.9,
#  469.9,
#  294.9,
#  191.9,
#  105.9,
#  169.9,
#  186.9,
#  241.0,
#  659.9,
#  120.0,
#  44.95,
#  44.95,
#  46.95,
#  54.9,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

pages=["https://www.migros.com.tr/beyaz-et-c-69",
       "https://www.migros.com.tr/beyaz-et-c-69?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/beyaz-et-c-69?sayfa=3&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        tavuk.append(price)

    driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
sakatat=[]
pages=["https://www.migros.com.tr/sakatat-c-3fd"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        sakatat.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/sarkuteri/c/1070?q=%3AbestSeller%3ApackageSize%3A1.000G&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
şarküteri = [float(price_element.get('content')) for price_element in price_elements]

şarküteri
# Out:
# [679.0,
#  1195.0,
#  799.9000000000001,
#  110.0,
#  1195.0,
#  999.9,
#  799.9000000000001,
#  1399.9,
#  419.9,
#  1299.9,
#  1179.9,
#  1899.9,
#  629.0,
#  1799.9,
#  1699.0,
#  979.9000000000001,
#  2119.9,
#  449.9,
#  1639.0,
#  759.9,
#  489.9,
#  629.0,
#  599.0,
#  650.0,
#  1399.9,
#  929.9000000000001,
#  599.9,
#  1299.9,
#  1090.0,
#  970.9000000000001,
#  1134.9,
#  999.9000000000001,
#  1399.9,
#  534.9,
#  1152.9,
#  759.9,
#  534.9,
#  2629.9,
#  557.9,
#  557.9,
#  1099.9,
#  2799.9,
#  1149.9,
#  999.9,
#  999.9,
#  999.9,
#  1299.9,
#  1299.9,
#  1100.9,
#  1299.9,
#  3479.9,
#  1399.9,
#  999.9,
#  769.9,
#  1100.9,
#  2199.9,
#  599.9,
#  2349.9,
#  930.0,
#  759.9,
#  1119.9,
#  2349.9,
#  2079.9,
#  739.9,
#  1139.9,
#  439.9,
#  1399.9,
#  879.9,
#  899.0000000000001,
#  2949.9,
#  955.0000000000001,
#  2399.9,
#  2549.9,
#  1999.9,
#  449.9,
#  999.9,
#  899.9000000000001,
#  890.0,
#  679.9,
#  1299.9,
#  1549.9,
#  85.9,
#  1159.9,
#  1359.9,
#  1199.9,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
sakatat=[]
pages=["https://www.migros.com.tr/et-sarkuteri-c-6b",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=6&sirala=onerilenler",
       "https://www.migros.com.tr/et-sarkuteri-c-6b?sayfa=7&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        şarküteri.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/balik-ve-deniz-mahsulleri/c/1098?q=%3AbestSeller%3Acategory%3A1099"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
tazebalık = [float(price_element.get('content')) for price_element in price_elements]

tazebalık
# Out:
# [159.99,
#  159.99,
#  299.99,
#  599.99,
#  279.99,
#  319.99,
#  349.99,
#  349.99,
#  249.99,
#  329.99,
#  179.99,
#  299.99,
#  249.99,
#  329.99,
#  299.99,
#  279.99]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/mevsim-baliklari-c-402?sayfa=1",
       "https://www.migros.com.tr/hazir-deniz-urunleri-c-403?sayfa=1"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        tazebalık.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/balik-ve-deniz-mahsulleri/c/1098?q=%3AbestSeller%3Acategory%3A1068"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
konservebalık = [float(price_element.get('content')) for price_element in price_elements]

konservebalık
# Out:
# [75.00000000000001,
#  79.99,
#  79.99,
#  204.99,
#  104.99,
#  189.9,
#  79.99,
#  159.99,
#  124.99,
#  134.99,
#  169.99,
#  239.99,
#  189.9,
#  259.99,
#  124.99,
#  189.9,
#  189.9,
#  184.99,
#  149.99,
#  169.99,
#  114.99,
#  179.99,
#  254.99,
#  284.99,
#  159.99,
#  419.99,
#  94.99,
#  204.99,
#  189.99,
#  189.99]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/dondurulmus-deniz-urunleri-c-2830?sayfa=1",
       "https://www.migros.com.tr/dondurulmus-deniz-urunleri-c-2830?sayfa=2&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        konservebalık.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/sut/c/1311?q=%3AbestSeller%3ApackageSize%3A1000ML&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
sut = [float(price_element.get('content')) for price_element in price_elements]

sut
# Out:
# [29.75,
#  28.0,
#  34.95,
#  39.95,
#  34.0,
#  35.95,
#  41.9,
#  44.75,
#  45.0,
#  99.94999999999999,
#  47.95,
#  39.95,
#  59.95,
#  42.95,
#  99.94999999999999,
#  39.95,
#  99.94999999999999,
#  99.94999999999999,
#  57.95,
#  64.95,
#  56.95,
#  99.94999999999999,
#  99.94999999999999,
#  99.94999999999999,
#  63.95,
#  41.5,
#  35.9,
#  49.949999999999996,
#  55.95,
#  42.9,
#  74.95,
#  35.95,
#  64.95,
#  43.95,
#  56.75,
#  59.95,
#  146.95,
#  99.94999999999999,
#  59.95,
#  99.94999999999999,
#  41.15,
#  59.95,
#  69.94999999999999,
#  65.0]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/uzun-omurlu-sut-c-40a?sayfa=1&markalar=170,731,404,349,425,434&sirala=onerilenler",
       "https://www.migros.com.tr/uzun-omurlu-sut-c-40a?sayfa=1&markalar=170,731,404,349,425,434&sirala=onerilenler",
       "https://www.migros.com.tr/uzun-omurlu-sut-c-40a?sayfa=1&markalar=170,731,404,349,425,434&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        sut.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/peynir/c/1318?q=%3AbestSeller%3ApackageSize%3A1.000G&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
peynir = [float(price_element.get('content')) for price_element in price_elements]

peynir
# Out:
# [350.0,
#  219.95,
#  139.5,
#  179.95,
#  79.0,
#  339.9,
#  299.9,
#  432.0,
#  475.9,
#  395.0,
#  190.0,
#  325.0,
#  420.0,
#  537.65,
#  525.0,
#  399.0,
#  295.0,
#  592.9,
#  501.5,
#  320.0,
#  485.00000000000006,
#  77.9,
#  1094.0,
#  975.0,
#  1026.9,
#  976.25,
#  1147.9,
#  1053.0,
#  450.0,
#  625.0,
#  976.25,
#  976.25,
#  976.25,
#  1094.0,
#  590.0,
#  425.0,
#  534.0,
#  774.5,
#  695.4,
#  864.5,
#  440.0,
#  440.0,
#  435.0,
#  592.9,
#  477.5,
#  653.5,
#  968.2,
#  320.0,
#  290.0,
#  575.0,
#  575.0,
#  575.0,
#  575.0,
#  450.0,
#  245.0,
#  550.0,
#  389.0,
#  1094.0,
#  976.25,
#  976.25,
#  859.0,
#  750.0,
#  420.0,
#  420.0,
#  440.0,
#  465.0,
#  447.9,
#  143.0,
#  469.0,
#  160.0,
#  415.0,
#  420.0,
#  420.0,
#  420.0,
#  599.95,
#  535.0,
#  470.0,
#  475.9,
#  625.0,
#  749.0,
#  525.0,
#  169.9,
#  1145.0,
#  598.45,
#  599.05,
#  469.9,
#  281.0,
#  99.9,
#  620.3,
#  999.95,
#  666.25,
#  598.2,
#  755.95,
#  976.25,
#  594.55,
#  976.25,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/peynir-c-6d",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=6&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=7&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=8&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=9&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=10&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=11&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=12&sirala=onerilenler",
       "https://www.migros.com.tr/peynir-c-6d?sayfa=13&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
           price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
           try:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/adet', '').replace('.', '').replace(',', '.'))
           except:
              price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             pass
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))
                    try:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                       amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                except:
                     pass
                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        peynir.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/yumurta/c/1349?q=%3AbestSeller&text=#"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('p', {"class": 'item-price-unit'})
yumurta = [float(span.get('content')) for p in price_elements for span in p.find_all('span') if span.get('content')]

yumurta
# Out:
# [3.17,
#  5.99,
#  2.3,
#  4.99,
#  6.57,
#  8.08,
#  9.49,
#  6.65,
#  9.98,
#  4.58,
#  6.39,
#  3.7,
#  2.82,
#  8.85,
#  4.58,
#  6.65,
#  4.32,
#  3.71,
#  8.13,
#  3.0,
#  6.99,
#  6.52,
#  10.58,
#  8.88,
#  10.58]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/yumurta-c-70?sayfa=1",

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        yumurta.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=tereya%C4%9F%C4%B1%3AbestSeller%3ApackageSize%3A1.000G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
tereyag = [float(price_element.get('content')) for price_element in price_elements]

tereyag
# Out:
# [299.0, 325.0, 539.0, 556.9, 440.0, 390.0, 201.9, 214.9, 318.9, 133.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/tereyagi-c-413?sayfa=1",
       "https://www.migros.com.tr/tereyagi-c-413?sayfa=2&sirala=onerilenler"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        
        price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        tereyag.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/margarin/c/1351?q=%3AbestSeller%3ApackageSize%3A250G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
margarin1 =[float(price_element.get('content')) for price_element in price_elements]
margarin1=4*np.array(margarin1)
url = "https://www.carrefoursa.com/margarin/c/1351?q=%3AbestSeller%3ApackageSize%3A500G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
margarin2 =[float(price_element.get('content')) for price_element in price_elements]
margarin2=2*np.array(margarin2)
margarin=list(itertools.chain(margarin1,margarin2))
margarin
# Out:
# [92.24,
#  154.0,
#  135.8,
#  135.6,
#  119.8,
#  155.8,
#  155.8,
#  155.8,
#  149.0,
#  108.5,
#  167.9,
#  147.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/margarin-c-414?sayfa=1"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        margarin.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/sivi-yaglar/c/1111?q=%3AbestSeller%3ApackageSize%3A1000ML"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
yag = [float(price_element.get('content')) for price_element in price_elements]

yag
# Out:
# [54.0,
#  457.0,
#  89.95,
#  424.95,
#  49.75,
#  419.9,
#  349.95,
#  429.95,
#  499.9,
#  359.95,
#  346.0,
#  439.95,
#  434.95,
#  449.95,
#  359.9,
#  429.95,
#  86.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/sivi-yag-c-76",
       "https://www.migros.com.tr/sivi-yag-c-76?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/sivi-yag-c-76?sayfa=3&sirala=onerilenler"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
        except:
             price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        yag.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/meyve/c/1015?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
meyve = [float(price_element.get('content')) for price_element in price_elements]

meyve
# Out:
# [7.8999999999999995,
#  18.68,
#  19.43,
#  56.18000000000001,
#  12.379999999999999,
#  39.68,
#  8.93,
#  29.93,
#  35.18,
#  79.99000000000001,
#  49.900000000000006,
#  42.68,
#  13.43,
#  29.93,
#  42.68,
#  40.43,
#  20.93,
#  29.93,
#  67.43,
#  49.900000000000006,
#  24.68,
#  69.9,
#  29.93,
#  57.68000000000001,
#  57.68000000000001,
#  37.43,
#  17.18,
#  44.93,
#  65.18,
#  35.93,
#  69.68,
#  37.43,
#  63.68000000000001,
#  56.21000000000001,
#  18.68,
#  56.93000000000001,
#  6.74,
#  29.96,
#  84.68,
#  65.93,
#  41.93,
#  89.93,
#  104.93,
#  172.43,
#  59.93000000000001,
#  109.43,
#  59.93000000000001,
#  82.43,
#  56.93000000000001,
#  74.96000000000001,
#  97.43,
#  79.43,
#  20.21,
#  74.96000000000001,
#  104.93,
#  37.43,
#  29.93,
#  67.43,
#  74.93,
#  86.18,
#  49.43000000000001,
#  20.18,
#  71.93,
#  112.43,
#  49.43000000000001,
#  59.96000000000001,
#  17.93]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/meyve-c-65?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-c-65?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-c-65?sayfa=3&sirala=onerilenler"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        meyve.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/kuru-meyve/c/1528?q=%3AbestSeller"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
kurumeyve = [float(price_element.get('content')) for price_element in price_elements]

kurumeyve
# Out:
# [44.93,
#  44.93,
#  299.92999999999995,
#  20.93,
#  75.0,
#  284.92999999999995,
#  59.93000000000001,
#  59.93000000000001,
#  74.93,
#  262.42999999999995,
#  344.92999999999995,
#  359.92999999999995,
#  449.92999999999995,
#  487.42999999999995,
#  284.92999999999995,
#  284.92999999999995,
#  322.42999999999995,
#  59.93000000000001,
#  81.0,
#  82.5,
#  82.5,
#  82.5,
#  82.5,
#  25.9,
#  59.9,
#  76.0]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=kuru%20meyve&sayfa=1&kategori=1089",
       "https://www.migros.com.tr/arama?q=kuru%20meyve&sayfa=2&kategori=1089",
       "https://www.migros.com.tr/arama?q=kuru%20meyve&sayfa=3&kategori=1089"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        kurumeyve.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/sebze/c/1025?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
sebze = [float(price_element.get('content')) for price_element in price_elements]

sebze
# Out:
# [9.899999999999999,
#  9.899999999999999,
#  7.99,
#  8.93,
#  29.93,
#  20.18,
#  19.950000000000003,
#  19.900000000000002,
#  12.68,
#  12.68,
#  34.43,
#  26.18,
#  19.49,
#  26.240000000000002,
#  34.43,
#  24.68,
#  35.18,
#  22.49,
#  12.68,
#  23.18,
#  29.9,
#  50.93000000000001,
#  26.18,
#  56.18000000000001,
#  32.18,
#  29.9,
#  22.43,
#  22.43,
#  16.88,
#  112.13,
#  24.68,
#  32.93,
#  17.18,
#  21.68,
#  29.93,
#  24.71,
#  22.46,
#  28.43,
#  24.68,
#  37.43,
#  117.68,
#  16.43,
#  20.96,
#  64.43,
#  29.96,
#  17.93,
#  112.43,
#  26.18,
#  35.18,
#  28.43,
#  101.18,
#  94.43,
#  37.49,
#  116.18,
#  37.46,
#  22.49,
#  34.43,
#  83.18,
#  170.58999999999997,
#  97.43,
#  26.96,
#  34.43,
#  121.45999999999998,
#  78.71000000000001,
#  209.95999999999998,
#  107.20999999999998,
#  67.46000000000001,
#  96.70999999999998,
#  56.93000000000001,
#  86.18,
#  78.71000000000001,
#  93.68,
#  89.93,
#  14.959999999999999,
#  51.68000000000001,
#  12.68,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/sebze-c-66?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/sebze-c-66?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/sebze-c-66?sayfa=3&sirala=onerilenler"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        sebze.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/yesil-sebze/c/1187?_sgm_campaign=category&_sgm_source=G%C4%B1da%2C+%C5%9Eekerleme+______+Konserveler+______+Ye%C5%9Fil+Sebze&_sgm_action=search&_sgm_term=konserve+sebze&_sgm_pinned=false"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
konservesebze = [float(price_element.get('content')) for price_element in price_elements]

konservesebze
# Out:
# [35.629999999999995,
#  33.53,
#  34.93,
#  38.43,
#  43.95,
#  51.9,
#  45.43000000000001,
#  45.43000000000001,
#  38.43,
#  43.9,
#  44.9,
#  24.43,
#  39.9]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=konserve%20sebze&sayfa=1&kategori=1106"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        konservesebze.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=re%C3%A7el%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
reçel = [float(price_element.get('content')) for price_element in price_elements]


url = "https://www.carrefoursa.com/search?q=marmelat%3AbestSeller%3Acategory%3A1310"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
marmelat = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/ballar/c/1362?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
bal = [float(price_element.get('content')) for price_element in price_elements]

recel=list(itertools.chain(reçel,bal,marmelat))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=re%C3%A7el&sayfa=1&kategori=115",
       "https://www.migros.com.tr/arama?q=re%C3%A7el&sayfa=2&kategori=115&sirala=akilli-siralama"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        recel.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=%C3%A7ikolata%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
cikolata = [float(price_element.get('content')) for price_element in price_elements]




url = "https://www.carrefoursa.com/cerez-cikolata-ve-biskuvi/c/1493?q=%3AbestSeller%3AinStockFlag%3Atrue%3Acategory%3A1501&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
sakız = [float(price_element.get('content')) for price_element in price_elements]



url = "https://www.carrefoursa.com/sekerleme/c/1494?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
sekerleme = [float(price_element.get('content')) for price_element in price_elements]

cikolata=list(itertools.chain(cikolata,sakız,sekerleme))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=1&kategori=1081",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=2&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=3&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=4&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=5&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=6&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=7&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=8&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=9&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=10&kategori=1081&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=1&kategori=1082",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=1&kategori=1083",
       "https://www.migros.com.tr/arama?q=%C3%A7ikolata&sayfa=1&kategori=1092"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        cikolata.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/kap-dondurma/c/1261?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
dondurma1 = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/tek-dondurma/c/1266?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
dondurma2 = [float(price_element.get('content')) for price_element in price_elements]
dondurma=list(itertools.chain(dondurma1,dondurma2))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=dondurma&sayfa=1&kategori=1051",
       "https://www.migros.com.tr/arama?q=dondurma&sayfa=2&kategori=1051&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=dondurma&sayfa=3&kategori=1051&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=dondurma&sayfa=4&kategori=1051&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=dondurma&sayfa=5&kategori=1051&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=dondurma&sayfa=6&kategori=1051&sirala=akilli-siralama"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        dondurma.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/kahve/c/1467?q=%3AbestSeller%3ApackageSize%3A250G&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
kahve = [float(price_element.get('content')) for price_element in price_elements]
kahve=4*np.array(kahve)
kahve=list(kahve)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=kahve&sayfa=1&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=2&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=3&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=4&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=5&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=6&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=7&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=8&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=9&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=10&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=11&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=12&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=13&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=14&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=15&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=kahve&sayfa=16&sirala=akilli-siralama"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        kahve.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=%C3%A7ay%3AbestSeller%3ApackageSize%3A500G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
cay1 = [float(price_element.get('content')) for price_element in price_elements]
cay1=2*np.array(cay1)

url = "https://www.carrefoursa.com/search?q=%C3%A7ay%3AbestSeller%3ApackageSize%3A1000G"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
cay2 = [float(price_element.get('content')) for price_element in price_elements]
cay2=np.array(cay2)

cay=list(itertools.chain(cay1,cay2))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=%C3%A7ay&sayfa=1&kategori=10433&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=%C3%A7ay&sayfa=2&kategori=10433&sirala=akilli-siralama"


       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        cay.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search/?text=kakao"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
kakao = [float(price_element.get('content')) for price_element in price_elements]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=kakao&sayfa=1&kategori=126"


       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        kakao.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/sular/c/1411?q=%3AbestSeller%3ApackageSize%3A1000ML"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
su1 = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/sular/c/1411?q=%3AbestSeller%3ApackageSize%3A500ML"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
su2 = [float(price_element.get('content')) for price_element in price_elements]
su2=2*np.array(su2)


url = "https://www.carrefoursa.com/search/?text=maden+suyu"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
maden = [float(price_element.get('content')) for price_element in price_elements]


su=list(itertools.chain(su1,su2,maden))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=su&sayfa=1&kategori=6&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=su&sayfa=2&kategori=6&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=su&sayfa=3&kategori=6&sirala=akilli-siralama"


       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        su.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/gazli-icecekler/c/1418?q=%3AbestSeller%3ApackageSize%3A1000ML"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
icecek = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/gazli-icecekler/c/1418?q=%3AbestSeller%3ApackageSize%3A250ML&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
icecek2 = [float(price_element.get('content')) for price_element in price_elements]
icecek2=4*np.array(icecek2)


icecek=list(itertools.chain(icecek,icecek2))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/gazli-icecek-c-80?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/gazli-icecek-c-80?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/gazli-icecek-c-80?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/gazli-icecek-c-80?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/gazli-icecek-c-80?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/gazli-icecek-c-80?sayfa=6&sirala=onerilenler",

       


       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        icecek.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/meyve-suyu/c/1430?q=%3AbestSeller%3ApackageSize%3A1000ML&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
meyvesuyu = [float(price_element.get('content')) for price_element in price_elements]


url = "https://www.carrefoursa.com/meyve-suyu/c/1430?q=%3AbestSeller%3ApackageSize%3A250ML&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
meyvesuyu2 = [float(price_element.get('content')) for price_element in price_elements]
meyvesuyu2=4*np.array(meyvesuyu2)
meyvesuyu=list(itertools.chain(meyvesuyu,meyvesuyu2))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/meyve-suyu-c-46c?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-suyu-c-46c?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-suyu-c-46c?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-suyu-c-46c?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/meyve-suyu-c-46c?sayfa=5&sirala=onerilenler",


       


       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        meyvesuyu.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/yogurt/c/1389?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
yogurt = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/search/?text=kaymak"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
kaymak = [float(price_element.get('content')) for price_element in price_elements]

digersut=list(itertools.chain(yogurt,kaymak))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=yo%C4%9Furt&sayfa=1&kategori=4&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=yo%C4%9Furt&sayfa=2&kategori=4&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=yo%C4%9Furt&sayfa=3&kategori=4&sirala=akilli-siralama",
       "https://www.migros.com.tr/arama?q=yo%C4%9Furt&sayfa=4&kategori=4&sirala=akilli-siralama",
       "https://www.migros.com.tr/ayran-c-47a?sayfa=1",
       "https://www.migros.com.tr/kefir-c-47b?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/kefir-c-47b?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/arama?q=kaymak&sayfa=1&kategori=4"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        digersut.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/search?q=%C5%9Feker%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
seker = [float(price_element.get('content')) for price_element in price_elements]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/arama?q=%C5%9Feker&sayfa=1&kategori=172"

       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        seker.append(price)

    driver.quit()

# %%
url = "https://www.carrefoursa.com/tursular-ve-salamuralar/c/1234?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
tursu = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/corbalar-ve-hazir-yemekler/c/1223?q=%3AbestSeller&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
corba = [float(price_element.get('content')) for price_element in price_elements]


url = "https://www.carrefoursa.com/ketcap-mayonez-ve-soslar/c/1209?q=%3AbestSeller%3AinStockFlag%3Atrue&show=All"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
ketcap = [float(price_element.get('content')) for price_element in price_elements]


url = "https://www.carrefoursa.com/cerez-cikolata-ve-biskuvi/c/1493?q=%3AbestSeller%3Acategory%3A1529%3AinStockFlag%3Atrue&text=#"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
bisküvi = [float(price_element.get('content')) for price_element in price_elements]

url = "https://www.carrefoursa.com/cerez-cikolata-ve-biskuvi/c/1493?q=%3AbestSeller%3AinStockFlag%3Atrue%3Acategory%3A1552"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')



price_elements=soup.find_all('span', {"class": 'item-price js-variant-discounted-price'})
cips = [float(price_element.get('content')) for price_element in price_elements]





digergıda=list(itertools.chain(tursu,corba,ketcap,bisküvi,cips))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
pages=["https://www.migros.com.tr/zeytin-c-71?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/zeytin-c-71?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/zeytin-c-71?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/zeytin-c-71?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/sos-c-113fc?sayfa=6&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=6&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=7&sirala=onerilenler",
       "https://www.migros.com.tr/tuz-baharat-harc-c-77?sayfa=8&sirala=onerilenler",
       "https://www.migros.com.tr/fasulye-c-2794?sayfa=1",
       "https://www.migros.com.tr/mercimek-c-113c9?sayfa=1",
       "https://www.migros.com.tr/nohut-c-2798?sayfa=1",
       "https://www.migros.com.tr/barbunya-c-2791?sayfa=1",
       "https://www.migros.com.tr/misir-c-2797?sayfa=1",
       "https://www.migros.com.tr/pismeye-hazir-etler-c-11fd7",
       "https://www.migros.com.tr/paketli-sandvic-c-2837",
       "https://www.migros.com.tr/meze-c-44e?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/meze-c-44e?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/kuruyemis-c-442?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/kuruyemis-c-442?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/kuruyemis-c-442?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/kuruyemis-c-442?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/kuruyemis-c-442?sayfa=5&sirala=onerilenler",
       "https://www.migros.com.tr/cips-c-440?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/cips-c-440?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/cips-c-440?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/cips-c-440?sayfa=4&sirala=onerilenler",
       "https://www.migros.com.tr/kek-c-43d?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/kek-c-43d?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/kek-c-43d?sayfa=3&sirala=onerilenler",
       "https://www.migros.com.tr/kraker-c-27ea?sayfa=1&sirala=onerilenler",
       "https://www.migros.com.tr/kraker-c-27ea?sayfa=2&sirala=onerilenler",
       "https://www.migros.com.tr/kraker-c-27ea?sayfa=3&sirala=onerilenler"
       ]
for page in pages:
    options = Options()
    options.headless = False

    # WebDriver'ı başlat
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    # URL'ye git
    url = page
    driver.get(url)


    time.sleep(10)


    soup = BeautifulSoup(driver.page_source, 'html.parser')


    unitprice_elements = soup.find_all('div', class_='unitPrice')


    prices = []
    for element in unitprice_elements:
        price_text = element.get_text(strip=True)
        try:
            price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
        except:
             try:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
             except:
                price_value = float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))
         
        prices.append(price_value)

    amount_elements = soup.find_all('span', class_='amount')
    for element in amount_elements:
                amount_text = element.get_text(strip=True)
                try:
                    amount_value = float(price_text.replace('(', '').replace(')', '').replace('TL', '').replace('.', '').replace(',', '.'))

                except:
                    try:
                        amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Kg', '').replace('.', '').replace(',', '.'))
                    except:
                        try:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Litre', '').replace('.', '').replace(',', '.'))
                        except:
                            amount_value=float(price_text.replace('(', '').replace(')', '').replace(' TL/Adet', '').replace('.', '').replace(',', '.'))

                prices.append(amount_value)

    # Fiyatları ekrana yazdır
    for price in prices:
        digergıda.append(price)

    driver.quit()

# %%
len(list(itertools.chain(pirincfiyatlarım,unfiyatlarım,fırınfiyatlarım,makarnafiyatlarım,tahıllar,danafiyatlarım,tavuk,şarküteri,konservebalık,sut,digersut,peynir,yumurta,tereyag,margarin,yag,meyve,kurumeyve,sebze,konservesebze,
                 seker,recel,cikolata,dondurma,digergıda,kahve,cay,kakao,su,icecek,meyvesuyu)))
# Out:
# 11142

# %%
import pandas as pd
endeks=pd.DataFrame()
endeks["Ürün"]=["Pirinç","Un","Fırın","Makarna","Tahıl","Dana/Kuzu Eti","Beyaz Et","Şarküteri","Taze Balık","Konserve Balık","Süt","Diğer Süt","Peynir","Yumurta","Tereyağ","Margarin","Sıvı Yağ","Taze Meyve","Kuru Meyve","Sebze",
                "Konserve Sebze","Şeker","Reçel/Bal/Marmelat","Çikolata","Dondurma","Diğer Gıda","Kahve","Çay","Kakao","Su","Alkolsüz İçecek","Meyve Suyu"]
endeks["Ağırlık"]=[1.5066,2.6153,5.0307,1.1980,0.4519,13.40,5.9841,3.0146,1.38059,0.4221,2.8092,2.47756,5.969153,3.03971,1.621039,0.589445,4.447344,7.753083,3.4848,12.19,3.8074,1.8088,1.3296,2.77696,0.7710,1.78,0.9847,2.840686,0.321618,1.7916,1.6724,0.728095]
endeks["Fiyat"]=[pirincfiyatlarım,unfiyatlarım,fırınfiyatlarım,makarnafiyatlarım,tahıllar,danafiyatlarım,tavuk,şarküteri,tazebalık,konservebalık,sut,digersut,peynir,yumurta,tereyag,margarin,yag,meyve,kurumeyve,sebze,konservesebze,
                 seker,recel,cikolata,dondurma,digergıda,kahve,cay,kakao,su,icecek,meyvesuyu]

for row in range(endeks.shape[0]):
    endeks["Fiyat"].iloc[row]=np.mean(endeks["Fiyat"].iloc[row])

endeks["Endeks"]=endeks["Fiyat"]*endeks["Ağırlık"]
endeks
# Out:
# C:\Users\Bora\AppData\Local\Temp\ipykernel_33712\3726590008.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   endeks["Fiyat"].iloc[row]=np.mean(endeks["Fiyat"].iloc[row])
# ...

# %%
data=pd.read_excel("endeksdata.xlsx")

data=data.set_index(pd.to_datetime(data["Tarih"]))
data=data.drop("Tarih",axis=1)
data
# Out:
#                Pirinç         Un      Fırın    Makarna      Tahıl  \
# Tarih
# 2024-07-30  97.500769  71.884444  88.552459  50.768619  53.368485
# 2024-07-31  98.204752  71.884444  86.312698  51.657833  53.544512
#
#             Dana/Kuzu Eti    Beyaz Et   Şarküteri  Taze Balık  Konserve Balık  \
# Tarih
# 2024-07-30     754.267759  213.559754  791.919342  773.434868      431.810204
# 2024-07-31     763.856348  209.602562  741.953819  534.433085      387.368200
#
#             ...  Reçel/Bal/Marmelat    Çikolata    Dondurma  Diğer Gıda  \
# Tarih       ...
# 2024-07-30  ...          198.925223  470.061989  304.103953  371.093667
# 2024-07-31  ...          208.157377  469.746857  249.468081  378.815951
#
#                  Kahve         Çay       Kakao         Su  Alkolsüz İçecek  \
# Tarih
# 2024-07-30  895.129611  370.752662  393.556071  55.994111        89.216188
# 2024-07-31  636.173096  372.281304  393.556071  55.619670        84.197040
#
#             Meyve Suyu
# Tarih
# ...

# %%
data=data.iloc[:1]

# %%
data1=pd.DataFrame()
for ürün in endeks["Ürün"].values:
    data1[ürün]=endeks[endeks["Ürün"]==ürün]["Fiyat"].values
data1.index=[pd.to_datetime(datetime.now().strftime("%Y-%m-%d"))]
data1.index.name="Tarih"
data=pd.concat([data,data1],axis=0)
data
# Out:
#                Pirinç         Un      Fırın    Makarna      Tahıl  \
# Tarih
# 2024-07-30  97.500769  71.884444  88.552459  50.768619  53.368485
# 2024-07-31  98.204752  71.884444  86.312698  51.657833  53.544512
#
#            Dana/Kuzu Eti    Beyaz Et   Şarküteri  Taze Balık Konserve Balık  \
# Tarih
# 2024-07-30    754.267759  213.559754  791.919342  773.434868     431.810204
# 2024-07-31    763.856348  188.087686  739.228017  534.433085       388.2382
#
#             ... Reçel/Bal/Marmelat    Çikolata    Dondurma  Diğer Gıda  \
# Tarih       ...
# 2024-07-30  ...         198.925223  470.061989  304.103953  371.093667
# 2024-07-31  ...         198.039262  491.287855  315.936485   374.73224
#
#                  Kahve         Çay       Kakao         Su Alkolsüz İçecek  \
# Tarih
# 2024-07-30  895.129611  370.752662  393.556071  55.994111       89.216188
# 2024-07-31    587.7926  382.629927  393.556071  57.716313        83.27075
#
#             Meyve Suyu
# Tarih
# ...

# %%
data.to_excel("endeksdata.xlsx")

# %%
products = list(data.keys())
data['Endeks'] = sum(data[product] * weight for product, weight in zip(products, endeks["Ağırlık"].values))
data
# Out:
#                Pirinç         Un      Fırın    Makarna      Tahıl  \
# Tarih
# 2024-07-30  97.500769  71.884444  88.552459  50.768619  53.368485
# 2024-07-31  98.204752  71.884444  86.312698  51.657833  53.544512
#
#            Dana/Kuzu Eti    Beyaz Et   Şarküteri  Taze Balık Konserve Balık  \
# Tarih
# 2024-07-30    754.267759  213.559754  791.919342  773.434868     431.810204
# 2024-07-31    763.856348  188.087686  739.228017  534.433085       388.2382
#
#             ...    Çikolata    Dondurma  Diğer Gıda       Kahve         Çay  \
# Tarih       ...
# 2024-07-30  ...  470.061989  304.103953  371.093667  895.129611  370.752662
# 2024-07-31  ...  491.287855  315.936485   374.73224    587.7926  382.629927
#
#                  Kakao         Su Alkolsüz İçecek  Meyve Suyu        Endeks
# Tarih
# 2024-07-30  393.556071  55.994111       89.216188   99.639107  35727.759588
# 2024-07-31  393.556071  57.716313        83.27075  107.301837  33467.158156
#
# [2 rows x 33 columns]

# %%
data.T
# Out:
# Tarih                 2024-07-30    2024-07-31
# Pirinç                 97.500769     98.204752
# Un                     71.884444     71.884444
# Fırın                  88.552459     86.312698
# Makarna                50.768619     51.657833
# Tahıl                  53.368485     53.544512
# Dana/Kuzu Eti         754.267759    763.856348
# Beyaz Et              213.559754    188.087686
# Şarküteri             791.919342    739.228017
# Taze Balık            773.434868    534.433085
# Konserve Balık        431.810204      388.2382
# Süt                   264.639086    245.126904
# Diğer Süt             172.122234    155.632781
# Peynir                427.099474    375.307366
# Yumurta                 7.265065      7.234156
# Tereyağ               493.344444    493.271124
# Margarin              615.849394     578.98623
# Sıvı Yağ              291.860674    301.802713
# Taze Meyve            252.991118    185.029108
# Kuru Meyve            697.990424    606.958963
# ...
